# %%
import pandas as pd
import numpy as np
data=pd.read_table(r'D:\EURUSD.txt',sep=',')
data.info()


data.head(5)
data.describe()
data['high']=data['<HIGH>']
data['low1']=data['<LOW>']
data['range']= data['high'] - data['low1']
data.head()
data['range'].describe()
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
#plt.figure(figsize=(16,8))
#plt.plot(data['range'])


data['range'].count()
type(data['range'])
niq = data['range'].unique()
niq = list(niq)
niq


allniq = list(data['range'])
type(data['range'])
type(data['range'].unique())
uniquedata = []
for i in niq:
    uniquedata.append(allniq.count(i))
#print(i)
#print(uniquedata)


#显示出频数统计表
list_all=[]
niq = list(niq)
uniquedata = list(uniquedata)




c={"niq" : niq,
   "uniquedata" : uniquedata}#将列表a，b转换成字典
data1=pdd.DataFrame(c)#将字典转换成为数据框
#data1


#data1.to_csv("HLarange.csv",sep=',')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6424286 entries, 0 to 6424285
# Data columns (total 8 columns):
# <TICKER>        object
# <DTYYYYMMDD>    int64
# <TIME>          int64
# <OPEN>          float64
# <HIGH>          float64
# <LOW>           float64
# <CLOSE>         float64
# <VOL>           int64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 392.1+ MB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf3e989bbac6> in <module>
#      45 c={"niq" : niq,
#      46    "uniquedata" : uniquedata}#将列表a，b转换成字典
# ---> 47 data1=pdd.DataFrame(c)#将字典转换成为数据框
#      48 #data1
#      49
#
# NameError: name 'pdd' is not defined

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("C:\\Users\\Administrator\\gold")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\gold'

# %%
data.head()
# Out:
#   <TICKER>  <DTYYYYMMDD>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  <VOL>  \
# 0   EURUSD      20010102  230100  0.9507  0.9507  0.9507   0.9507      4
# 1   EURUSD      20010102  230200  0.9506  0.9506  0.9505   0.9505      4
# 2   EURUSD      20010102  230300  0.9505  0.9507  0.9505   0.9506      4
# 3   EURUSD      20010102  230400  0.9506  0.9506  0.9506   0.9506      4
# 4   EURUSD      20010102  230500  0.9506  0.9506  0.9506   0.9506      4
#
#      high    low1   range
# 0  0.9507  0.9507  0.0000
# 1  0.9506  0.9505  0.0001
# 2  0.9507  0.9505  0.0002
# 3  0.9506  0.9506  0.0000
# 4  0.9506  0.9506  0.0000

# %%
#删除/选取某列含有特定数值的行
df1=data[data['range'].isin([0.0000])] # 选取df1中A列包含数字1的行
df1
#通过~取反，选取不包含数字1的行
df2=data[~data['range'].isin([0.0000])]
df2
# Out:
#         <TICKER>  <DTYYYYMMDD>  <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 1         EURUSD      20010102  230200  0.9506  0.9506  0.9505   0.9505
# 2         EURUSD      20010102  230300  0.9505  0.9507  0.9505   0.9506
# 6         EURUSD      20010102  230700  0.9505  0.9507  0.9505   0.9507
# 10        EURUSD      20010102  231100  0.9507  0.9507  0.9506   0.9507
# 15        EURUSD      20010102  231600  0.9507  0.9507  0.9506   0.9506
# 25        EURUSD      20010102  233700  0.9507  0.9508  0.9507   0.9508
# 34        EURUSD      20010102  235000  0.9507  0.9508  0.9506   0.9506
# 38        EURUSD      20010102  235400  0.9507  0.9507  0.9506   0.9506
# 43        EURUSD      20010102  235900  0.9507  0.9507  0.9506   0.9506
# 44        EURUSD      20010103       0  0.9506  0.9507  0.9506   0.9507
# 49        EURUSD      20010103     500  0.9507  0.9507  0.9506   0.9507
# 50        EURUSD      20010103     600  0.9507  0.9507  0.9506   0.9506
# ...

# %%
#所有1分钟振幅变化
Hdata = list(df2["high"])
Ldata = list(df2["low1"])
plt.figure(figsize=(168,10))
plt.plot(Hdata[0:])
plt.plot(Ldata[0:])
plt.title("1 min H-L Range")
plt.xlim(0,4168612)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#所有1min 波动幅度，回归均值（5、20、。。）
plt.figure(figsize=(168,50))
plt.xlim(0,6424285)
plt.plot(df2["range"][0:],c="red",alpha =0.9)
